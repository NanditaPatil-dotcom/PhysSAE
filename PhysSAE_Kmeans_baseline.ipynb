# %% [markdown]
# <a href="https://colab.research.google.com/github/NanditaPatil-dotcom/PhysSAE/blob/main/PhysSAE_Kmeans_baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Setup

# %%
import os, time, math
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import matplotlib as mpl
from sklearn.cluster import KMeans

# reproducibility
torch.manual_seed(0); np.random.seed(0)
torch.set_num_threads(4)

# publication style
mpl.rcParams.update({
    "figure.dpi": 110, "savefig.dpi": 220,
    "font.family": "serif", "font.serif": ["DejaVu Serif"],
    "mathtext.fontset": "cm",
    "axes.titlesize": 11, "axes.labelsize": 10,
    "xtick.labelsize": 9, "ytick.labelsize": 9,
    "legend.fontsize": 9,
    "axes.spines.top": False, "axes.spines.right": False,
})

os.makedirs("artifacts", exist_ok=True)
os.makedirs("figures", exist_ok=True)

# hyperparams
HIDDEN = 40        # PINN hidden width
N_LAYERS = 4       # number of hidden linear layers
PINN_ITERS = 4000
N_CLUSTERS = 128

# %% [markdown]
# # 2. PINN architecture

# %%
class PINN(nn.Module):
    def __init__(self, out_dim=1, layers=None):
        super().__init__()

        layers = layers or ([2] +[HIDDEN]*N_LAYERS +[out_dim])

        self.net = nn.ModuleList(
            [nn.Linear(layers[i], layers[i+1])
             for i in range(len(layers)-1)]
        )

        self.act = nn.Tanh()

        for m in self.net:
            nn.init.xavier_normal_(m.weight)
            nn.init.zeros_(m.bias)

        self._hidden = None

    def forward(self,x,t):
        h = torch.cat([x,t],dim=1)

        for layer in self.net[:-1]:
            h = self.act(layer(h))

        self._hidden = h

        return self.net[-1](h)

# %% [markdown]
# # 3. Training PINN

# %%
def train_pinn(loss_fn, n_iter=PINN_ITERS, log_every=400, tag="pinn",out_dim=1):
    model = PINN(out_dim=out_dim)
    opt = torch.optim.Adam(model.parameters(), lr=1e-3)
    hist = []; t0 = time.time()
    for it in range(n_iter):
        opt.zero_grad()
        loss, parts = loss_fn(model)
        loss.backward(); opt.step()
        hist.append(parts)
        if it % log_every == 0:
            print(f"[{tag}] it {it:5d} | bc {parts[0]:.2e} ic {parts[1]:.2e} f {parts[2]:.2e} | {time.time()-t0:.0f}s")
    print(f"[{tag}] total {time.time()-t0:.0f}s")
    return model, np.array(hist)

# %% [markdown]
# # 4. Train on PDEs

# %% [markdown]
# ## 1. Train the Burgers PINN

# %%
nu = 0.01/np.pi
def burgers_loss(model):
    n_b, n_i, n_f = 100, 100, 2500
    x_b1 = -torch.ones(n_b,1); x_b2 = torch.ones(n_b,1); t_b = torch.rand(n_b,1)
    x_i = torch.rand(n_i,1)*2-1; t_i = torch.zeros(n_i,1); u_i = -torch.sin(np.pi*x_i)
    x_f = torch.rand(n_f,1)*2-1; t_f = torch.rand(n_f,1)
    u_b1, u_b2, u_ip = model(x_b1, t_b), model(x_b2, t_b), model(x_i, t_i)
    xfg, tfg = x_f.clone().requires_grad_(True), t_f.clone().requires_grad_(True)
    u = model(xfg, tfg)
    u_t = torch.autograd.grad(u, tfg, torch.ones_like(u), create_graph=True)[0]
    u_x = torch.autograd.grad(u, xfg, torch.ones_like(u), create_graph=True)[0]
    u_xx = torch.autograd.grad(u_x, xfg, torch.ones_like(u_x), create_graph=True)[0]
    r = u_t + u*u_x - nu*u_xx
    l_bc = (u_b1**2).mean() + (u_b2**2).mean()
    l_ic = ((u_ip - u_i)**2).mean()
    l_f  = (r**2).mean()
    return 100*l_bc + 100*l_ic + l_f, (l_bc.item(), l_ic.item(), l_f.item())

if os.path.exists("artifacts/burgers_pinn.pt"):
    pinn_b = PINN(out_dim=1); pinn_b.load_state_dict(torch.load("artifacts/burgers_pinn.pt"))
    hist_b = np.load("artifacts/burgers_hist.npy")
    print("Loaded cached Burgers PINN.")
else:
    pinn_b, hist_b = train_pinn(burgers_loss, tag="burgers")
    torch.save(pinn_b.state_dict(), "artifacts/burgers_pinn.pt")
    np.save("artifacts/burgers_hist.npy", hist_b)
# Out:
# [burgers] it     0 | bc 1.10e-02 ic 5.70e-01 f 1.29e-02 | 0s
# [burgers] it   400 | bc 1.10e-03 ic 8.67e-03 f 7.04e-01 | 7s
# [burgers] it   800 | bc 4.77e-04 ic 7.83e-04 f 4.56e-01 | 14s
# [burgers] it  1200 | bc 3.47e-04 ic 3.61e-04 f 4.19e-01 | 21s
# [burgers] it  1600 | bc 1.82e-04 ic 1.95e-04 f 4.21e-01 | 29s
# [burgers] it  2000 | bc 1.11e-04 ic 2.32e-04 f 4.05e-01 | 36s
# [burgers] it  2400 | bc 2.06e-04 ic 1.84e-04 f 4.13e-01 | 43s
# [burgers] it  2800 | bc 4.33e-05 ic 1.25e-04 f 3.53e-01 | 50s
# [burgers] it  3200 | bc 1.80e-04 ic 2.56e-04 f 3.65e-01 | 57s
# [burgers] it  3600 | bc 1.67e-03 ic 4.62e-04 f 3.67e-01 | 65s
# [burgers] total 72s

# %% [markdown]
# ## 2. Train the Allen–Cahn PINN

# %%
D_AC = 1e-4
def allencahn_loss(model):
    n_b, n_i, n_f = 100, 100, 2500
    t_b = torch.rand(n_b,1)
    x_bl = -torch.ones(n_b,1); x_br = torch.ones(n_b,1)
    x_i = torch.rand(n_i,1)*2-1; t_i = torch.zeros(n_i,1)
    u_i = (x_i**2) * torch.cos(np.pi*x_i)
    x_f = torch.rand(n_f,1)*2-1; t_f = torch.rand(n_f,1)
    # periodic BC: u(-1,t)=u(1,t) and u_x(-1,t)=u_x(1,t)
    xbl_g, xbr_g = x_bl.clone().requires_grad_(True), x_br.clone().requires_grad_(True)
    u_bl, u_br = model(xbl_g, t_b), model(xbr_g, t_b)
    u_bl_x = torch.autograd.grad(u_bl, xbl_g, torch.ones_like(u_bl), create_graph=True)[0]
    u_br_x = torch.autograd.grad(u_br, xbr_g, torch.ones_like(u_br), create_graph=True)[0]
    l_bc = ((u_bl-u_br)**2).mean() + ((u_bl_x-u_br_x)**2).mean()
    u_ip = model(x_i, t_i); l_ic = ((u_ip - u_i)**2).mean()
    xfg, tfg = x_f.clone().requires_grad_(True), t_f.clone().requires_grad_(True)
    u = model(xfg, tfg)
    u_t = torch.autograd.grad(u, tfg, torch.ones_like(u), create_graph=True)[0]
    u_x = torch.autograd.grad(u, xfg, torch.ones_like(u), create_graph=True)[0]
    u_xx = torch.autograd.grad(u_x, xfg, torch.ones_like(u_x), create_graph=True)[0]
    r = u_t - D_AC*u_xx + 5.0*u**3 - 5.0*u
    l_f = (r**2).mean()
    return 100*l_bc + 100*l_ic + l_f, (l_bc.item(), l_ic.item(), l_f.item())

if os.path.exists("artifacts/allencahn_pinn.pt"):
    pinn_a = PINN(out_dim=1); pinn_a.load_state_dict(torch.load("artifacts/allencahn_pinn.pt"))
    hist_a = np.load("artifacts/allencahn_hist.npy")
    print("Loaded cached Allen-Cahn PINN.")
else:
    pinn_a, hist_a = train_pinn(allencahn_loss, tag="allencahn")
    torch.save(pinn_a.state_dict(), "artifacts/allencahn_pinn.pt")
    np.save("artifacts/allencahn_hist.npy", hist_a)
# Out:
# [allencahn] it     0 | bc 3.69e-02 ic 1.12e-01 f 1.38e-01 | 0s
# [allencahn] it   400 | bc 2.12e-03 ic 2.07e-02 f 1.16e+00 | 7s
# [allencahn] it   800 | bc 8.14e-04 ic 3.23e-03 f 1.07e+00 | 15s
# [allencahn] it  1200 | bc 5.53e-04 ic 1.31e-03 f 1.03e+00 | 23s
# [allencahn] it  1600 | bc 1.75e-04 ic 8.39e-04 f 9.82e-01 | 30s
# [allencahn] it  2000 | bc 3.41e-04 ic 5.95e-04 f 9.79e-01 | 37s
# [allencahn] it  2400 | bc 1.46e-04 ic 7.61e-04 f 1.08e+00 | 45s
# [allencahn] it  2800 | bc 8.46e-05 ic 7.73e-04 f 9.64e-01 | 52s
# [allencahn] it  3200 | bc 1.03e-04 ic 7.99e-04 f 1.01e+00 | 60s
# [allencahn] it  3600 | bc 8.15e-05 ic 9.58e-04 f 9.20e-01 | 67s
# [allencahn] total 75s

# %% [markdown]
# ## 3. Heat Equation

# %%
def heat_loss(model):
    n_b, n_i, n_f = 100, 100, 2500
    x_b1 = -torch.ones(n_b,1)
    x_b2 =  torch.ones(n_b,1)
    t_b = torch.rand(n_b,1)
    u_b1 = model(x_b1, t_b)
    u_b2 = model(x_b2, t_b)
    x_i = 2*torch.rand(n_i,1) - 1
    t_i = torch.zeros(n_i,1)
    u_i_true = torch.exp(-5*x_i**2)
    u_i = model(x_i, t_i)
    x_f = 2*torch.rand(n_f,1) - 1
    t_f = torch.rand(n_f,1)
    xfg = x_f.clone().requires_grad_(True)
    tfg = t_f.clone().requires_grad_(True)
    u = model(xfg, tfg)
    u_t = torch.autograd.grad(u,tfg,torch.ones_like(u),create_graph=True)[0]
    u_x = torch.autograd.grad(u,xfg,torch.ones_like(u),create_graph=True)[0]
    u_xx = torch.autograd.grad(u_x,xfg,torch.ones_like(u_x),create_graph=True)[0]

    r = u_t - u_xx

    l_bc = (u_b1**2).mean() + (u_b2**2).mean()
    l_ic = ((u_i - u_i_true)**2).mean()
    l_f = (r**2).mean()
    total = 100*l_bc + 100*l_ic + l_f
    return total, (l_bc.item(),l_ic.item(),l_f.item())

if os.path.exists("artifacts/heat_pinn.pt"):
    pinn_h = PINN(out_dim=1)
    pinn_h.load_state_dict(torch.load("artifacts/heat_pinn.pt"))
    hist_h = np.load("artifacts/heat_hist.npy")
    print("Loaded cached Heat PINN.")
else:
    pinn_h, hist_h = train_pinn(heat_loss,tag="heat")
    torch.save(pinn_h.state_dict(),"artifacts/heat_pinn.pt")
    np.save("artifacts/heat_hist.npy",hist_h)
# Out:
# [heat] it     0 | bc 1.51e-01 ic 3.47e-01 f 1.63e-01 | 0s
# [heat] it   400 | bc 5.80e-04 ic 2.92e-03 f 3.62e-01 | 7s
# [heat] it   800 | bc 4.20e-04 ic 7.76e-04 f 1.70e-01 | 14s
# [heat] it  1200 | bc 2.65e-04 ic 4.71e-04 f 9.77e-02 | 21s
# [heat] it  1600 | bc 1.42e-04 ic 2.70e-04 f 5.95e-02 | 28s
# [heat] it  2000 | bc 8.54e-05 ic 1.85e-04 f 3.60e-02 | 34s
# [heat] it  2400 | bc 6.82e-05 ic 1.51e-04 f 2.13e-02 | 41s
# [heat] it  2800 | bc 5.51e-05 ic 6.39e-05 f 1.72e-02 | 48s
# [heat] it  3200 | bc 2.23e-04 ic 7.96e-05 f 1.40e-02 | 54s
# [heat] it  3600 | bc 1.08e-05 ic 3.01e-05 f 1.22e-02 | 59s
# [heat] total 65s

# %% [markdown]
# ## 4. schrodinger equation - single soliton

# %%
def schrodinger_loss_single(model):

    n_b, n_i, n_f = 100, 100, 2500
    x_b1 = -5*torch.ones(n_b,1)
    x_b2 =  5*torch.ones(n_b,1)
    t_b  = torch.rand(n_b,1)
    uv_b1 = model(x_b1,t_b)
    uv_b2 = model(x_b2,t_b)
    u_b1 = uv_b1[:,0:1]
    v_b1 = uv_b1[:,1:2]
    u_b2 = uv_b2[:,0:1]
    v_b2 = uv_b2[:,1:2]

    x_i = -5 + 10*torch.rand(n_i,1)
    t_i = torch.zeros(n_i,1)

    uv_i = model(x_i,t_i)

    u_i = uv_i[:,0:1]
    v_i = uv_i[:,1:2]

    u_true = 2.0 / torch.cosh(x_i)
    v_true = torch.zeros_like(x_i)

    x_f = -5 + 10*torch.rand(n_f,1)
    t_f = torch.rand(n_f,1)
    xfg = x_f.clone().requires_grad_(True)
    tfg = t_f.clone().requires_grad_(True)
    uv = model(xfg,tfg)
    u = uv[:,0:1]
    v = uv[:,1:2]

    u_t = torch.autograd.grad(u, tfg,torch.ones_like(u),create_graph=True)[0]
    v_t = torch.autograd.grad(v, tfg,torch.ones_like(v),create_graph=True)[0]
    u_x = torch.autograd.grad(u, xfg,torch.ones_like(u),create_graph=True)[0]
    v_x = torch.autograd.grad(v, xfg,torch.ones_like(v),create_graph=True)[0]
    u_xx = torch.autograd.grad(u_x, xfg,torch.ones_like(u_x),create_graph=True)[0]
    v_xx = torch.autograd.grad(v_x, xfg,torch.ones_like(v_x),create_graph=True)[0]
    amp2 = u*u + v*v
    r_u = u_t + 0.5*v_xx + amp2*v
    r_v = v_t - 0.5*u_xx - amp2*u
    l_bc = ((u_b1**2).mean()+ (v_b1**2).mean()+ (u_b2**2).mean()+ (v_b2**2).mean())
    l_ic = (((u_i-u_true)**2).mean()+ ((v_i-v_true)**2).mean())
    l_f = ((r_u**2).mean()+ (r_v**2).mean())
    total = 100*l_bc + 100*l_ic + l_f

    return total, (l_bc.item(),l_ic.item(),l_f.item())


if os.path.exists("artifacts/schrodinger_pinn_single.pt"):
    pinn_s_s = PINN(out_dim=2)
    pinn_s_s.load_state_dict(torch.load("artifacts/schrodinger_pinn_single.pt"))
    hist_s_s = np.load("artifacts/schrodinger_hist_single.npy")
    print("Loaded cached Schrödinger single PINN.")

else:
    pinn_s_s, hist_s_s = train_pinn(schrodinger_loss_single,tag="schrodinger single",out_dim=2)
    torch.save(pinn_s_s.state_dict(),"artifacts/schrodinger_pinn_single.pt")
    np.save("artifacts/schrodinger_hist_single.npy",hist_s_s)
# Out:
# [schrodinger single] it     0 | bc 8.39e-01 ic 1.03e+00 f 2.95e-02 | 0s
# [schrodinger single] it   400 | bc 2.24e-04 ic 1.20e-03 f 6.64e-01 | 10s
# [schrodinger single] it   800 | bc 7.24e-05 ic 5.37e-04 f 4.29e-01 | 21s
# [schrodinger single] it  1200 | bc 4.39e-05 ic 2.20e-04 f 3.39e-01 | 31s
# [schrodinger single] it  1600 | bc 4.14e-05 ic 1.41e-04 f 2.27e-01 | 41s
# [schrodinger single] it  2000 | bc 5.14e-05 ic 1.62e-04 f 1.91e-01 | 52s
# [schrodinger single] it  2400 | bc 1.97e-04 ic 1.93e-04 f 1.63e-01 | 64s
# [schrodinger single] it  2800 | bc 1.89e-04 ic 1.19e-04 f 1.65e-01 | 76s
# [schrodinger single] it  3200 | bc 3.28e-05 ic 7.29e-05 f 1.59e-01 | 88s
# [schrodinger single] it  3600 | bc 5.95e-05 ic 8.82e-05 f 1.37e-01 | 100s
# [schrodinger single] total 112s

# %% [markdown]
# ## 5. schrodinger equation - moving soliton

# %%
def schrodinger_loss_moving(model):

    n_b, n_i, n_f = 100, 100, 2500
    x_b1 = -5*torch.ones(n_b,1)
    x_b2 =  5*torch.ones(n_b,1)
    t_b  = torch.rand(n_b,1)
    uv_b1 = model(x_b1,t_b)
    uv_b2 = model(x_b2,t_b)
    u_b1 = uv_b1[:,0:1]
    v_b1 = uv_b1[:,1:2]
    u_b2 = uv_b2[:,0:1]
    v_b2 = uv_b2[:,1:2]
    x_i = -5 + 10*torch.rand(n_i,1)
    t_i = torch.zeros(n_i,1)

    uv_i = model(x_i,t_i)

    u_i = uv_i[:,0:1]
    v_i = uv_i[:,1:2]

    eta = 2.0
    v0  = 2.0

    amp0 = eta / torch.cosh(eta*x_i)

    u_true = amp0 * torch.cos(v0*x_i)
    v_true = amp0 * torch.sin(v0*x_i)
    x_f = -5 + 10*torch.rand(n_f,1)
    t_f = torch.rand(n_f,1)
    xfg = x_f.clone().requires_grad_(True)
    tfg = t_f.clone().requires_grad_(True)
    uv = model(xfg,tfg)
    u = uv[:,0:1]
    v = uv[:,1:2]

    u_t = torch.autograd.grad(u, tfg,torch.ones_like(u),create_graph=True)[0]
    v_t = torch.autograd.grad(v, tfg,torch.ones_like(v),create_graph=True)[0]
    u_x = torch.autograd.grad(u, xfg,torch.ones_like(u),create_graph=True)[0]
    v_x = torch.autograd.grad(v, xfg,torch.ones_like(v),create_graph=True)[0]
    u_xx = torch.autograd.grad(u_x, xfg,torch.ones_like(u_x),create_graph=True)[0]
    v_xx = torch.autograd.grad(v_x, xfg,torch.ones_like(v_x),create_graph=True)[0]
    amp2 = u*u + v*v
    r_u = u_t + 0.5*v_xx + amp2*v
    r_v = v_t - 0.5*u_xx - amp2*u
    l_bc = ((u_b1**2).mean()+ (v_b1**2).mean()+ (u_b2**2).mean()+ (v_b2**2).mean())
    l_ic = (((u_i-u_true)**2).mean()+ ((v_i-v_true)**2).mean())
    l_f = ((r_u**2).mean()+ (r_v**2).mean())
    total = 100*l_bc + 100*l_ic + l_f

    return total, (l_bc.item(),l_ic.item(),l_f.item())


try:
    if os.path.exists("artifacts/schrodinger_pinn_moving.pt") and \
       os.path.exists("artifacts/schrodinger_hist_moving.npy"):
        pinn_s_m = PINN(out_dim=2)
        pinn_s_m.load_state_dict(torch.load("artifacts/schrodinger_pinn_moving.pt"))
        hist_s_m = np.load("artifacts/schrodinger_hist_moving.npy")
        print("Loaded cached Schrödinger moving PINN.")

    else:
        pinn_s_m, hist_s_m = train_pinn(schrodinger_loss_moving,tag="schrodinger moving",out_dim=2)
        torch.save(pinn_s_m.state_dict(),"artifacts/schrodinger_pinn_moving.pt")
        np.save("artifacts/schrodinger_hist_moving.npy",hist_s_m)

except FileNotFoundError:
    print("Cached files not found or inaccessible; retraining Schrödinger moving PINN.")
    pinn_s_m, hist_s_m = train_pinn(schrodinger_loss_moving,tag="schrodinger moving",out_dim=2)
    torch.save(pinn_s_m.state_dict(),"artifacts/schrodinger_pinn_moving.pt")
    np.save("artifacts/schrodinger_hist_moving.npy",hist_s_m)
# Out:
# [schrodinger moving] it     0 | bc 4.17e-01 ic 4.80e-01 f 8.31e-02 | 0s
# [schrodinger moving] it   400 | bc 4.70e-04 ic 5.20e-03 f 7.07e-01 | 12s
# [schrodinger moving] it   800 | bc 2.86e-04 ic 2.06e-03 f 3.42e-01 | 24s
# [schrodinger moving] it  1200 | bc 2.37e-04 ic 8.85e-04 f 2.05e-01 | 36s
# [schrodinger moving] it  1600 | bc 5.40e-05 ic 3.26e-04 f 1.88e-01 | 48s
# [schrodinger moving] it  2000 | bc 3.17e-05 ic 2.44e-04 f 1.39e-01 | 60s
# [schrodinger moving] it  2400 | bc 4.34e-05 ic 1.52e-04 f 1.25e-01 | 72s
# [schrodinger moving] it  2800 | bc 1.61e-05 ic 7.71e-05 f 9.61e-02 | 84s
# [schrodinger moving] it  3200 | bc 2.76e-05 ic 7.82e-05 f 7.92e-02 | 96s
# [schrodinger moving] it  3600 | bc 1.77e-05 ic 5.24e-05 f 7.90e-02 | 108s
# [schrodinger moving] total 120s

# %% [markdown]
# ## 6. Convection equation

# %%
def convection_loss(model, beta):

    n_b, n_i, n_f = 100, 100, 2500

    # periodic BC
    t_b = torch.rand(n_b,1)
    x_bl = -torch.ones(n_b,1)
    x_br =  torch.ones(n_b,1)
    u_bl = model(x_bl, t_b)
    u_br = model(x_br, t_b)

    # periodic derivative BC
    xbl_g = x_bl.clone().requires_grad_(True)
    xbr_g = x_br.clone().requires_grad_(True)

    u_bl_g = model(xbl_g, t_b)
    u_br_g = model(xbr_g, t_b)

    u_bl_x = torch.autograd.grad(u_bl_g,xbl_g,torch.ones_like(u_bl_g),create_graph=True)[0]
    u_br_x = torch.autograd.grad(u_br_g,xbr_g,torch.ones_like(u_br_g),create_graph=True)[0]
    l_bc = ((u_bl - u_br)**2).mean() + ((u_bl_x - u_br_x)**2).mean()

    # initial condition

    x_i = 2*torch.rand(n_i,1) - 1
    t_i = torch.zeros(n_i,1)

    u_true = torch.sin(np.pi*x_i)

    u_i = model(x_i,t_i)

    l_ic = ((u_i - u_true)**2).mean()

    # residual points

    x_f = 2*torch.rand(n_f,1) - 1
    t_f = torch.rand(n_f,1)

    xfg = x_f.clone().requires_grad_(True)
    tfg = t_f.clone().requires_grad_(True)

    u = model(xfg,tfg)
    u_t = torch.autograd.grad(u,tfg,torch.ones_like(u),create_graph=True)[0]
    u_x = torch.autograd.grad(u,xfg,torch.ones_like(u),create_graph=True)[0]

    r = u_t + beta*u_x
    l_f = (r**2).mean()
    total = 100*l_bc + 100*l_ic + l_f
    return total, (l_bc.item(),l_ic.item(),l_f.item())

BETAS = [1,50]

conv_models = {}
conv_hists  = {}

for beta in BETAS:

    fname_model = f"artifacts/convection_beta{beta}.pt"
    fname_hist  = f"artifacts/convection_beta{beta}_hist.npy"

    if os.path.exists(fname_model):

        model = PINN(out_dim=1)
        model.load_state_dict(torch.load(fname_model))
        hist = np.load(fname_hist)
        print(f"Loaded cached convection PINN beta={beta}")

    else:

        loss_fn = lambda m, b=beta: convection_loss(m,b)
        model, hist = train_pinn(loss_fn,tag=f"conv_beta{beta}")
        torch.save(model.state_dict(),fname_model)
        np.save(fname_hist,hist)

    conv_models[beta] = model
    conv_hists[beta]  = hist
# Out:
# [conv_beta1] it     0 | bc 1.22e+00 ic 9.77e-01 f 3.24e-01 | 0s
# [conv_beta1] it   400 | bc 2.50e-03 ic 1.11e-02 f 1.02e+00 | 5s
# [conv_beta1] it   800 | bc 5.66e-04 ic 1.25e-03 f 8.46e-01 | 11s
# [conv_beta1] it  1200 | bc 5.37e-04 ic 1.04e-03 f 6.57e-01 | 16s
# [conv_beta1] it  1600 | bc 9.09e-04 ic 6.61e-04 f 5.79e-01 | 22s
# [conv_beta1] it  2000 | bc 1.37e-03 ic 6.40e-04 f 5.13e-01 | 27s
# [conv_beta1] it  2400 | bc 5.82e-04 ic 1.55e-04 f 4.44e-01 | 33s
# [conv_beta1] it  2800 | bc 2.48e-04 ic 1.73e-04 f 3.81e-01 | 38s
# [conv_beta1] it  3200 | bc 4.44e-04 ic 1.89e-04 f 3.44e-01 | 44s
# [conv_beta1] it  3600 | bc 5.65e-04 ic 3.01e-04 f 2.96e-01 | 49s
# [conv_beta1] total 55s
# [conv_beta50] it     0 | bc 3.06e-01 ic 7.31e-01 f 1.98e+02 | 0s
# [conv_beta50] it   400 | bc 6.78e-03 ic 5.16e-01 f 1.98e+00 | 5s
# [conv_beta50] it   800 | bc 5.65e-02 ic 1.88e-01 f 1.65e+00 | 10s
# [conv_beta50] it  1200 | bc 3.53e-02 ic 8.66e-02 f 4.59e+00 | 16s
# [conv_beta50] it  1600 | bc 1.10e-02 ic 3.78e-02 f 9.97e-01 | 21s
# [conv_beta50] it  2000 | bc 5.27e-02 ic 3.51e-02 f 1.63e+00 | 26s
# [conv_beta50] it  2400 | bc 1.14e-02 ic 2.19e-02 f 2.24e+00 | 31s
# [conv_beta50] it  2800 | bc 3.44e-02 ic 1.66e-02 f 1.88e+00 | 37s
# [conv_beta50] it  3200 | bc 1.05e-02 ic 1.18e-02 f 9.97e-01 | 42s
# [conv_beta50] it  3600 | bc 1.40e-02 ic 5.48e-03 f 2.48e+00 | 47s
# [conv_beta50] total 52s

# %% [markdown]
# # 5. Evaluate All PINNs on a dense grid

# %%
nx, nt = 256, 100
xs = torch.linspace(-1, 1, nx).reshape(-1,1)
ts = torch.linspace(0, 1, nt).reshape(-1,1)
X, T = torch.meshgrid(xs.squeeze(), ts.squeeze(), indexing='ij')
XF, TF = X.reshape(-1,1), T.reshape(-1,1)
np.save("artifacts/grid_x.npy", xs.numpy().squeeze())
np.save("artifacts/grid_t.npy", ts.numpy().squeeze())

def eval_pinn_and_hidden(model):
    with torch.no_grad():
        U = model(XF, TF).reshape(nx, nt).numpy()
        H = model._hidden.detach().reshape(nx, nt, HIDDEN).numpy()
    return U, H

def eval_schrodinger_and_hidden(model):

    with torch.no_grad():
        UV = model(XF,TF)
        U = UV[:,0].reshape(nx,nt).numpy()
        V = UV[:,1].reshape(nx,nt).numpy()
        H = (model._hidden.detach().reshape(nx,nt,HIDDEN).numpy())
    return U,V,H

U_b, H_b = eval_pinn_and_hidden(pinn_b)
np.save("artifacts/burgers_U.npy", U_b)
np.save("artifacts/burgers_H.npy", H_b)

U_a, H_a = eval_pinn_and_hidden(pinn_a)
np.save("artifacts/allencahn_U.npy", U_a)
np.save("artifacts/allencahn_H.npy", H_a)

U_h, H_h = eval_pinn_and_hidden(pinn_h)
np.save("artifacts/heat_U.npy",U_h)
np.save("artifacts/heat_H.npy",H_h)

U_s_s, V_s_s, H_s_s = eval_schrodinger_and_hidden(pinn_s_s)
np.save("artifacts/schrodinger_u_single.npy", U_s_s)
np.save("artifacts/schrodinger_v_single.npy", V_s_s)
np.save("artifacts/schrodinger_H_single.npy", H_s_s)
AMP_s_s = np.sqrt(U_s_s**2 + V_s_s**2)
np.save("artifacts/schrodinger_amp_single.npy",AMP_s_s)
PHI_s_s = np.arctan2(V_s_s, U_s_s)
np.save("artifacts/schrodinger_phi_single.npy",PHI_s_s)

U_s_m, V_s_m, H_s_m = eval_schrodinger_and_hidden(pinn_s_m)
np.save("artifacts/schrodinger_u_moving.npy", U_s_m)
np.save("artifacts/schrodinger_v_moving.npy", V_s_m)
np.save("artifacts/schrodinger_H_moving.npy", H_s_m)
AMP_s_m = np.sqrt(U_s_m**2 + V_s_m**2)
np.save("artifacts/schrodinger_amp_moving.npy",AMP_s_m)
PHI_s_m = np.arctan2(V_s_m, U_s_m)
np.save("artifacts/schrodinger_phi_moving.npy",PHI_s_m)

# Successful convection (beta=1)
U_c1, H_c1 = eval_pinn_and_hidden(conv_models[1])
np.save("artifacts/convection_beta1_U.npy", U_c1)
np.save("artifacts/convection_beta1_H.npy", H_c1)

# Failed convection (beta=50)
U_c50, H_c50 = eval_pinn_and_hidden(conv_models[50])
np.save("artifacts/convection_beta50_U.npy", U_c50)
np.save("artifacts/convection_beta50_H.npy", H_c50)

print(f"Burgers   U range [{U_b.min():.3f}, {U_b.max():.3f}], H shape {H_b.shape}")
print(f"AllenCahn U range [{U_a.min():.3f}, {U_a.max():.3f}], H shape {H_a.shape}")
print(f"Heat     U range "f"[{U_h.min():.3f}, {U_h.max():.3f}], "f"H shape {H_h.shape}")
print("Schrodinger-single:", U_s_s.shape, V_s_s.shape, H_s_s.shape)
print("Schrodinger-moving:", U_s_m.shape, V_s_m.shape, H_s_m.shape)
print(f"Conv β=1   U range [{U_c1.min():.3f}, {U_c1.max():.3f}], "f"H shape {H_c1.shape}")
print(f"Conv β=50  U range [{U_c50.min():.3f}, {U_c50.max():.3f}], "f"H shape {H_c50.shape}")
# Out:
# Burgers   U range [-0.975, 0.984], H shape (256, 100, 40)
# AllenCahn U range [-0.919, 0.073], H shape (256, 100, 40)
# Heat     U range [-0.011, 0.993], H shape (256, 100, 40)
# Schrodinger-single: (256, 100) (256, 100) (256, 100, 40)
# Schrodinger-moving: (256, 100) (256, 100) (256, 100, 40)
# Conv β=1   U range [-0.992, 1.004], H shape (256, 100, 40)
# Conv β=50  U range [-0.877, 0.891], H shape (256, 100, 40)

# %%
# Schrödinger evaluation on native domain [-5,5]
nx_s, nt_s = 256, 100
xs_s = torch.linspace(-5, 5, nx_s).reshape(-1,1)
ts_s = torch.linspace(0, 1, nt_s).reshape(-1,1)

Xs, Ts = torch.meshgrid(xs_s.squeeze(),ts_s.squeeze(),indexing="ij")
XF_s = Xs.reshape(-1,1)
TF_s = Ts.reshape(-1,1)

# ---------- Single soliton ----------
with torch.no_grad():

    UV = pinn_s_s(XF_s, TF_s)

    U_s_fig_single = UV[:,0].reshape(nx_s, nt_s).numpy()
    V_s_fig_single = UV[:,1].reshape(nx_s, nt_s).numpy()

AMP_s_fig_single = np.sqrt(U_s_fig_single**2 +V_s_fig_single**2)
UX_s_fig_single = np.abs(
    np.gradient(AMP_s_fig_single,xs_s.squeeze().numpy()[1]-xs_s.squeeze().numpy()[0],axis=0))

# ---------- Moving soliton ----------
with torch.no_grad():

    UV = pinn_s_m(XF_s, TF_s)
    U_s_fig_moving = UV[:,0].reshape(nx_s, nt_s).numpy()
    V_s_fig_moving = UV[:,1].reshape(nx_s, nt_s).numpy()

AMP_s_fig_moving = np.sqrt(U_s_fig_moving**2 +V_s_fig_moving**2)
UX_s_fig_moving = np.abs(
    np.gradient(AMP_s_fig_moving,xs_s.squeeze().numpy()[1]-xs_s.squeeze().numpy()[0],axis=0))

extent_s = [0,1,-5,5]

# ------------------------------------------------------------

xs_np = xs.numpy().squeeze()
ts_np = ts.numpy().squeeze()

extent = [ts_np.min(),ts_np.max(),xs_np.min(),xs_np.max()]

# %% [markdown]
# # 6. KMeans

# %%
# Activation normalization
def normalize(H_flat):
    mu = H_flat.mean(0, keepdims=True)
    sd = H_flat.std(0, keepdims=True) + 1e-6
    return (H_flat - mu) / sd, mu, sd

# Flatten hidden activations
H_b_flat   = H_b.reshape(-1, HIDDEN)
H_a_flat   = H_a.reshape(-1, HIDDEN)
H_h_flat   = H_h.reshape(-1, HIDDEN)
H_s_s_flat = H_s_s.reshape(-1, HIDDEN)
H_s_m_flat = H_s_m.reshape(-1, HIDDEN)
H_c1_flat  = H_c1.reshape(-1, HIDDEN)
H_c50_flat = H_c50.reshape(-1, HIDDEN)


# Normalize
H_b_n,   mu_b,   sd_b   = normalize(H_b_flat)
H_a_n,   mu_a,   sd_a   = normalize(H_a_flat)
H_h_n,   mu_h,   sd_h   = normalize(H_h_flat)
H_s_s_n, mu_s_s, sd_s_s = normalize(H_s_s_flat)
H_s_m_n, mu_s_m, sd_s_m = normalize(H_s_m_flat)
H_c1_n,  mu_c1,  sd_c1  = normalize(H_c1_flat)
H_c50_n, mu_c50, sd_c50 = normalize(H_c50_flat)


# K-Means helper
def run_kmeans(H_norm):

    kmeans = KMeans(n_clusters=N_CLUSTERS,random_state=0,n_init=20)
    labels = kmeans.fit_predict(H_norm)

    # Distance to every centroid
    D = kmeans.transform(H_norm)

    # Convert distance into feature activations
    Z = -D

    print(f"K-Means inertia = {kmeans.inertia_:.3f}")

    return kmeans, Z, labels


# Fit K-Means
kmeans_b,   Z_b,   labels_b   = run_kmeans(H_b_n)
kmeans_a,   Z_a,   labels_a   = run_kmeans(H_a_n)
kmeans_h,   Z_h,   labels_h   = run_kmeans(H_h_n)
kmeans_s_s, Z_s_s, labels_s_s = run_kmeans(H_s_s_n)
kmeans_s_m, Z_s_m, labels_s_m = run_kmeans(H_s_m_n)
kmeans_c1,  Z_c1,  labels_c1  = run_kmeans(H_c1_n)
kmeans_c50, Z_c50, labels_c50 = run_kmeans(H_c50_n)


# Reshape back into spatial fields
Z_b   = Z_b.reshape(nx, nt, N_CLUSTERS)
Z_a   = Z_a.reshape(nx, nt, N_CLUSTERS)
Z_h   = Z_h.reshape(nx, nt, N_CLUSTERS)
Z_s_s = Z_s_s.reshape(nx, nt, N_CLUSTERS)
Z_s_m = Z_s_m.reshape(nx, nt, N_CLUSTERS)
Z_c1  = Z_c1.reshape(nx, nt, N_CLUSTERS)
Z_c50 = Z_c50.reshape(nx, nt, N_CLUSTERS)


# Save K-Means parameters
for name, model, labels in [

    ("burgers", kmeans_b, labels_b),
    ("allencahn", kmeans_a, labels_a),
    ("heat", kmeans_h, labels_h),
    ("schrodinger_single", kmeans_s_s, labels_s_s),
    ("schrodinger_moving", kmeans_s_m, labels_s_m),
    ("convection_beta1", kmeans_c1, labels_c1),
    ("convection_beta50", kmeans_c50, labels_c50),

]:

    np.save(
        f"artifacts/{name}_kmeans_centers.npy",
        model.cluster_centers_
    )

    np.save(
        f"artifacts/{name}_kmeans_labels.npy",
        labels
    )


# Save feature maps
np.save("artifacts/burgers_clusters.npy", Z_b)
np.save("artifacts/allencahn_clusters.npy", Z_a)
np.save("artifacts/heat_clusters.npy", Z_h)
np.save("artifacts/schrodinger_single_clusters.npy", Z_s_s)
np.save("artifacts/schrodinger_moving_clusters.npy", Z_s_m)
np.save("artifacts/convection_beta1_clusters.npy", Z_c1)
np.save("artifacts/convection_beta50_clusters.npy", Z_c50)


# Summary

for name, model in [

    ("Burgers", kmeans_b),
    ("Allen-Cahn", kmeans_a),
    ("Heat", kmeans_h),
    ("Schrodinger (Single)", kmeans_s_s),
    ("Schrodinger (Moving)", kmeans_s_m),
    ("Conv β=1", kmeans_c1),
    ("Conv β=50", kmeans_c50),

]:

    print(
        f"{name:25s}"
        f" inertia = {model.inertia_:12.3f}"
    )
# Out:
# K-Means inertia = 11774.566
# K-Means inertia = 11012.409
# K-Means inertia = 9588.349
# K-Means inertia = 8590.481
# K-Means inertia = 9089.452
# K-Means inertia = 10728.647
# K-Means inertia = 3714.862
# Burgers                   inertia =    11774.566
# Allen-Cahn                inertia =    11012.409
# Heat                      inertia =     9588.349
# Schrodinger (Single)      inertia =     8590.481
# Schrodinger (Moving)      inertia =     9089.452
# Conv β=1                  inertia =    10728.647
# Conv β=50                 inertia =     3714.862

# %% [markdown]
# # 7. Defining the ground-truth concept fields

# %%
def concepts_burgers(U, xs, ts):
    dx = xs[1]-xs[0]; dt = ts[1]-ts[0]
    u_x = np.gradient(U, dx, axis=0); u_t = np.gradient(U, dt, axis=1)
    u_xx = np.gradient(u_x, dx, axis=0)
    nx, nt = U.shape
    return {
        "|u|": np.abs(U),
        "|u_x| (shock)": np.abs(u_x),
        "|u_t|": np.abs(u_t),
        "u (signed)": U,
        "|u_xx| (curvature)": np.abs(u_xx),
        "dist to x=0": np.tile(np.abs(xs).reshape(-1,1), (1, nt)),
        "t (time)": np.tile(ts.reshape(1,-1), (nx, 1)),
    }

def concepts_allencahn(U, xs, ts):
    dx = xs[1]-xs[0]; dt = ts[1]-ts[0]
    u_x = np.gradient(U, dx, axis=0); u_t = np.gradient(U, dt, axis=1)
    nx, nt = U.shape
    return {
        "|u|": np.abs(U),
        "|u_x| (interface)": np.abs(u_x),
        "|u_t|": np.abs(u_t),
        "u (signed)": U,
        "u^3 (reaction)": U**3,
        "interface (exp(-u^2/0.1))": np.exp(-U**2/0.1),
        "t (time)": np.tile(ts.reshape(1,-1), (nx, 1)),
    }
def concepts_heat(U, xs, ts):
    dx = xs[1] - xs[0]
    dt = ts[1] - ts[0]
    u_x = np.gradient(U, dx, axis=0)
    u_t = np.gradient(U, dt, axis=1)
    u_xx = np.gradient(u_x, dx, axis=0)
    nx, nt = U.shape
    return {
        "|u|": np.abs(U),
        "|u_x| (gradient)": np.abs(u_x),
        "|u_t|": np.abs(u_t),
        "|u_xx| (curvature)": np.abs(u_xx),
        "t (time)": np.tile(ts.reshape(1,-1),(nx,1))
    }
def concepts_schrodinger_single(U, V, AMP, PHI, xs, ts):

    dx = xs[1]-xs[0]
    dt = ts[1]-ts[0]
    u_x = np.gradient(U, dx, axis=0)
    v_x = np.gradient(V, dx, axis=0)
    u_t = np.gradient(U, dt, axis=1)
    v_t = np.gradient(V, dt, axis=1)
    h_x = np.sqrt(u_x**2 + v_x**2)
    h_t = np.sqrt(u_t**2 + v_t**2)

    return {
        "|h| (amplitude)" : AMP,
        "u (real)" : U,
        "v (imag)" : V,
        "|h_x| (wave-front)" : h_x,
        "|h_t| (temporal)" : h_t,
        "phi (phase)" : PHI,
        "t (time)" : np.tile(ts.reshape(1,-1),(len(xs),1))
    }

def concepts_schrodinger_moving(U, V, AMP, PHI, xs, ts):
    dx = xs[1] - xs[0]
    dt = ts[1] - ts[0]
    # Spatial derivatives
    u_x = np.gradient(U, dx, axis=0)
    v_x = np.gradient(V, dx, axis=0)
    # Temporal derivatives
    u_t = np.gradient(U, dt, axis=1)
    v_t = np.gradient(V, dt, axis=1)
    h_x = np.sqrt(u_x**2 + v_x**2)
    h_t = np.sqrt(u_t**2 + v_t**2)
    # Learned soliton trajectory
    peak_idx = np.argmax(AMP, axis=0)
    peak_x = xs[peak_idx]

    X, T = np.meshgrid(xs, ts, indexing="ij")
    center = peak_x[None, :]          # shape (1, nt)
    dist_center = np.abs(X - center)
    return {
        "|h| (amplitude)": AMP,
        "u (real)": U,
        "v (imag)": V,
        "|h_x| (wave-front)": h_x,
        "|h_t| (temporal)": h_t,
        "phi (phase)": PHI,
        "distance to moving soliton center": dist_center,
    }

def concepts_convection(U, xs, ts, beta):
    dx = xs[1] - xs[0]
    dt = ts[1] - ts[0]
    u_x = np.gradient(U, dx, axis=0)
    u_t = np.gradient(U, dt, axis=1)
    nx, nt = U.shape
    X = np.tile(xs.reshape(-1,1), (1, nt))
    T = np.tile(ts.reshape(1,-1), (nx, 1))
    concepts = {
        "|u|" : np.abs(U),
        "|u_x| (transport front)" : np.abs(u_x),
        "|u_t|" : np.abs(u_t),
        "u (signed)" : U,
        "x position" : X,
        "t (time)" : T,
    }

    if beta == 1:
        concepts["characteristic (x-t)"] = X - T
    else:
        concepts[f"characteristic (x-{beta}t)"] = X - beta*T

    return concepts

# Convert grid to NumPy
xs_np = xs.numpy().squeeze()
ts_np = ts.numpy().squeeze()
# Schrödinger grids
xs_s_np = np.linspace(-5, 5, U_s_s.shape[0])
ts_s_np = np.linspace(0, 1, U_s_s.shape[1])

C_b = concepts_burgers(U_b, xs_np, ts_np)
C_a = concepts_allencahn(U_a, xs_np, ts_np)
C_h = concepts_heat(U_h, xs_np, ts_np)
C_s_s = concepts_schrodinger_single(U_s_s,V_s_s,AMP_s_s,PHI_s_s,xs_s_np,ts_s_np)
C_s_m = concepts_schrodinger_moving(U_s_m,V_s_m,AMP_s_m,PHI_s_m,xs_s_np,ts_s_np)
C_c1 = concepts_convection(U_c1,xs_np,ts_np, beta=1)
C_c50 = concepts_convection(U_c50,xs_np,ts_np, beta=50)

np.savez("artifacts/burgers_concepts.npz", **C_b)
np.savez("artifacts/allencahn_concepts.npz", **C_a)
np.savez("artifacts/heat_concepts.npz",**C_h)
np.savez("artifacts/schrodinger_single_concepts.npz", **C_s_s)
np.savez("artifacts/schrodinger_moving_concepts.npz", **C_s_m)
np.savez("artifacts/convection_beta1_concepts.npz",**C_c1)
np.savez("artifacts/convection_beta50_concepts.npz",**C_c50)

print("Burgers concepts  :", list(C_b.keys()))
print("AllenCahn concepts:", list(C_a.keys()))
print("Heat concepts     :", list(C_h.keys()))
print("Schrodinger (Single) concepts  :", list(C_s_s.keys()))
print("Schrodinger (Moving) concepts  :", list(C_s_m.keys()))
print("Conv β=1 concepts:",list(C_c1.keys()))
print("Conv β=50 concepts:",list(C_c50.keys()))
# Out:
# Burgers concepts  : ['|u|', '|u_x| (shock)', '|u_t|', 'u (signed)', '|u_xx| (curvature)', 'dist to x=0', 't (time)']
# AllenCahn concepts: ['|u|', '|u_x| (interface)', '|u_t|', 'u (signed)', 'u^3 (reaction)', 'interface (exp(-u^2/0.1))', 't (time)']
# Heat concepts     : ['|u|', '|u_x| (gradient)', '|u_t|', '|u_xx| (curvature)', 't (time)']
# Schrodinger (Single) concepts  : ['|h| (amplitude)', 'u (real)', 'v (imag)', '|h_x| (wave-front)', '|h_t| (temporal)', 'phi (phase)', 't (time)']
# Schrodinger (Moving) concepts  : ['|h| (amplitude)', 'u (real)', 'v (imag)', '|h_x| (wave-front)', '|h_t| (temporal)', 'phi (phase)', 'distance to moving soliton center']
# Conv β=1 concepts: ['|u|', '|u_x| (transport front)', '|u_t|', 'u (signed)', 'x position', 't (time)', 'characteristic (x-t)']
# Conv β=50 concepts: ['|u|', '|u_x| (transport front)', '|u_t|', 'u (signed)', 'x position', 't (time)', 'characteristic (x-50t)']

# %% [markdown]
# # 8. KMeans–concept alignment matrix

# %% [markdown]
# ## Main code

# %%
def alignment(Z_field, concepts):
    K = Z_field.shape[-1]
    names = list(concepts.keys())
    A = np.zeros((K, len(names)))

    for k in range(K):
        zk = Z_field[..., k].flatten()

        if zk.std() < 1e-8:
            continue

        zk = (zk - zk.mean()) / (zk.std() + 1e-12)

        for j, name in enumerate(names):
            c = concepts[name].flatten()

            if c.std() < 1e-8:
                continue

            c = (c - c.mean()) / (c.std() + 1e-12)

            A[k, j] = (zk * c).mean()

    return A, names

A_b, names_b = alignment(Z_b, C_b)
A_a, names_a = alignment(Z_a, C_a)
A_h, names_h = alignment(Z_h, C_h)
A_s_s, names_s_s = alignment(Z_s_s, C_s_s)
A_s_m, names_s_m = alignment(Z_s_m, C_s_m)
A_c1, names_c1 = alignment(Z_c1,C_c1)
A_c50, names_c50 = alignment(Z_c50,C_c50)

np.save("artifacts/burgers_kmeans_alignment.npy", A_b)
np.save("artifacts/allencahn_kmeans_alignment.npy", A_a)
np.save("artifacts/heat_kmeans_alignment.npy", A_h)
np.save("artifacts/schrodinger_single_kmeans_alignment.npy", A_s_s)
np.save("artifacts/schrodinger_moving_kmeans_alignment.npy", A_s_m)
np.save("artifacts/convection_beta1_kmeans_alignment.npy", A_c1)
np.save("artifacts/convection_beta50_kmeans_alignment.npy", A_c50)
print("Alignment done.")
# Out:
# Alignment done.

# %% [markdown]
# ## Top cluster per concept

# %%
def print_table(A,names, label):
    print(f"\n{label}:")
    print(f"{'concept':30s} | {'top cluster':>9s} | {'K Means r':>7s}")
    print("-"*70)
    for j, name in enumerate(names):
        k_km = int(np.argmax(np.abs(A[:, j])))
        print(f"{name:30s} | atom {k_km:3d}  | {A[k_km,j]:+.3f}")
print_table(A_b, names_b, "Burgers")
print_table(A_a, names_a, "Allen-Cahn")
print_table(A_h, names_h, "Heat")
print_table(A_s_s, names_s_s, "Schrodinger (Single)")
print_table(A_s_m, names_s_m, "Schrodinger (Moving)")
print_table(A_c1,names_c1,"Convection β=1")
print_table(A_c50,names_c50,"Convection β=50")
# Out:
# Burgers:
# concept                        | top cluster | K Means r
# ----------------------------------------------------------------------
# |u|                            | atom 102  | +0.364
# |u_x| (shock)                  | atom  79  | -0.262
# |u_t|                          | atom  95  | +0.580
# u (signed)                     | atom  48  | -0.849
# |u_xx| (curvature)             | atom   6  | +0.447
# dist to x=0                    | atom  69  | -0.815
# t (time)                       | atom  95  | -0.625
#
# Allen-Cahn:
# concept                        | top cluster | K Means r
# ----------------------------------------------------------------------
# |u|                            | atom  10  | -0.710
# |u_x| (interface)              | atom  10  | -0.685
# |u_t|                          | atom 117  | -0.747
# u (signed)                     | atom  63  | +0.675
# u^3 (reaction)                 | atom   1  | +0.453
# interface (exp(-u^2/0.1))      | atom 117  | +0.676
# t (time)                       | atom 104  | -0.739
#
# Heat:
# concept                        | top cluster | K Means r
# ----------------------------------------------------------------------
# |u|                            | atom 120  | +0.829
# |u_x| (gradient)               | atom 112  | -0.827
# |u_t|                          | atom 120  | +0.607
# |u_xx| (curvature)             | atom 120  | +0.548
# t (time)                       | atom  44  | +0.771
#
# Schrodinger (Single):
# concept                        | top cluster | K Means r
# ----------------------------------------------------------------------
# |h| (amplitude)                | atom 116  | +0.842
# u (real)                       | atom  99  | +0.863
# v (imag)                       | atom  84  | +0.963
# |h_x| (wave-front)             | atom  79  | -0.721
# |h_t| (temporal)               | atom  99  | +0.956
# phi (phase)                    | atom  41  | +0.917
# t (time)                       | atom  41  | +0.823
#
# Schrodinger (Moving):
# concept                        | top cluster | K Means r
# ----------------------------------------------------------------------
# |h| (amplitude)                | atom 125  | +0.950
# u (real)                       | atom  82  | +0.937
# v (imag)                       | atom  87  | +0.900
# |h_x| (wave-front)             | atom  85  | +0.941
# |h_t| (temporal)               | atom  28  | -0.687
# phi (phase)                    | atom  90  | -0.857
# distance to moving soliton center | atom  40  | -0.873
#
# Convection β=1:
# concept                        | top cluster | K Means r
# ----------------------------------------------------------------------
# |u|                            | atom  41  | -0.449
# |u_x| (transport front)        | atom  47  | +0.444
# |u_t|                          | atom  47  | +0.483
# u (signed)                     | atom 112  | -0.809
# x position                     | atom  36  | +0.935
# t (time)                       | atom   9  | +0.818
# characteristic (x-t)           | atom  59  | +0.975
#
# Convection β=50:
# concept                        | top cluster | K Means r
# ----------------------------------------------------------------------
# |u|                            | atom 105  | -0.601
# |u_x| (transport front)        | atom  75  | -0.802
# |u_t|                          | atom  30  | +0.846
# u (signed)                     | atom 100  | +0.638
# x position                     | atom  25  | -0.197
# t (time)                       | atom  85  | +0.449
# characteristic (x-50t)         | atom  53  | -0.449

# %% [markdown]
# ## Alignment matrices-KMeans

# %%
def fig2(A_dict, names_dict):

    tags = ["Burgers","Allen-Cahn","Heat","Schrodinger (Single)","Schrodinger (Moving)","Conv β=1","Conv β=50"]
    fig, axes = plt.subplots(len(tags),1,figsize=(8, 28),constrained_layout=True)

    for row, tag in enumerate(tags):

        A = A_dict[tag]
        names = names_dict[tag]

        # ---------------- K Means ----------------

        rows = [int(np.argmax(np.abs(A[:, j])))for j in range(A.shape[1])]
        rows_u = list(dict.fromkeys(rows))
        A_show = A[rows_u]
        ax = axes[row]
        vmax = max(np.abs(A_show).max(), 1e-3)
        im = ax.imshow(A_show,cmap="RdBu_r",vmin=-vmax,vmax=vmax,aspect="auto")
        ax.set_xticks(range(len(names)))
        ax.set_xticklabels(names,rotation=35,ha="right",fontsize=8)
        ax.set_yticks(range(len(rows_u)))
        ax.set_yticklabels([f"atom {k}" for k in rows_u],fontsize=8)
        ax.set_title(f"{tag} — KMeans clusters concept alignment\n(top atom per concept)")
        plt.colorbar(im,ax=ax,fraction=0.04,label="Pearson r")


    plt.savefig("figures/fig2_alignment.png",bbox_inches="tight")
    plt.show()


fig2(
    {"Burgers": A_b,"Allen-Cahn": A_a,"Heat": A_h,"Schrodinger (Single)": A_s_s,"Schrodinger (Moving)": A_s_m,"Conv β=1": A_c1,"Conv β=50": A_c50,},
    {"Burgers": names_b,"Allen-Cahn": names_a,"Heat": names_h,"Schrodinger (Single)": names_s_s,"Schrodinger (Moving)": names_s_m,"Conv β=1": names_c1,"Conv β=50": names_c50,}
)

# %% [markdown]
# ##  Spatial structure of the top atoms

# %%
def fig3(d_list):

    fig, axes = plt.subplots(7,8,figsize=(18, 19),constrained_layout=True)
    for row, (Z, A, names, concept_subset, tag) in enumerate(d_list):
        current_extent = extent_s if "Schrodinger" in tag else extent
        for j_idx, cname in enumerate(concept_subset):

            j = names.index(cname)
            k_top = int(np.argmax(np.abs(A[:, j])))
            r = A[k_top, j]
            zk = Z[..., k_top]
            ax = axes[row, j_idx]
            vmax = zk.max()
            vmax = np.abs(zk).max()
            im = ax.imshow(zk,extent=current_extent,origin="lower",aspect="auto",cmap="coolwarm",vmin=-vmax,vmax=vmax)
            ax.set_title(f"{tag}: Cluster {k_top}\n↔ {cname} (r={r:+.2f})",fontsize=9)
            ax.set_xlabel("$t$")

            if j_idx == 0:
                ax.set_ylabel("$x$")

            plt.colorbar(im,ax=ax,fraction=0.046)

        # hide unused columns
        for k in range(len(concept_subset), 8):
            axes[row, k].axis("off")

    plt.savefig("figures/fig3_ica.png",bbox_inches="tight")
    plt.show()


burgers_concepts_show = ["u (signed)","|u_x| (shock)","dist to x=0","t (time)"]
ac_concepts_show = ["u (signed)","|u_x| (interface)","interface (exp(-u^2/0.1))","t (time)"]
heat_concepts_show = ["|u|","|u_x| (gradient)","|u_t|","|u_xx| (curvature)","t (time)"]
sch_single_concepts_show = ["|h| (amplitude)","u (real)","v (imag)","|h_x| (wave-front)","|h_t| (temporal)","phi (phase)","t (time)"]
sch_moving_concepts_show = ["|h| (amplitude)","u (real)","v (imag)","|h_x| (wave-front)","|h_t| (temporal)","phi (phase)","distance to moving soliton center"]
conv1_concepts_show = ["|u|","|u_x| (transport front)","|u_t|","u (signed)","x position","t (time)","characteristic (x-t)"]
conv50_concepts_show = ["|u|","|u_x| (transport front)","|u_t|","u (signed)","x position","t (time)","characteristic (x-50t)"]


fig3([(Z_b, A_b, names_b, burgers_concepts_show, "Burgers"),
      (Z_a, A_a, names_a,ac_concepts_show,"Allen-Cahn"),
      (Z_h, A_h, names_h,heat_concepts_show,"Heat"),
      (Z_s_s, A_s_s, names_s_s,sch_single_concepts_show,"Schrodinger (Single)"),
      (Z_s_m, A_s_m, names_s_m,sch_moving_concepts_show,"Schrodinger (Moving)"),
      (Z_c1, A_c1, names_c1,conv1_concepts_show,"Conv β=1"),
      (Z_c50, A_c50, names_c50,conv50_concepts_show,"Conv β=50")])

# %% [markdown]
# # 9. Ablation — closed-loop causal check - Figure 4

# %% [markdown]
# ## ablation func for - burgers,allen cahn,heat,conv

# %%
def intervene_ablate_kmeans(pinn, kmeans, H, mu, sd, cluster_idx):

    # Flatten hidden activations
    H_flat = H.reshape(-1, HIDDEN)
    # Normalize
    H_norm = (H_flat - mu) / sd
    # Distances to every centroid
    D = kmeans.transform(H_norm)
    #Temperature
    T = 1.0
    # Soft assignment weights
    sigma = 0.25 * np.median(D)
    W = np.exp(-(D**2) / (2 * sigma**2))
    W /= W.sum(axis=1, keepdims=True)
    # Reconstruction
    H_recon_norm = W @ kmeans.cluster_centers_
    # Ablate one cluster
    W_mod = W.copy()
    # Remove one centroid
    W_mod[:, cluster_idx] = 0.0
    # Renormalize
    W_mod /= W_mod.sum(axis=1, keepdims=True) + 1e-12
    H_mod_norm = W_mod @ kmeans.cluster_centers_
    # Undo normalization
    H_recon = H_recon_norm * sd + mu
    H_mod   = H_mod_norm   * sd + mu
    # Frozen PINN readout
    W = pinn.net[-1].weight.detach().numpy()
    b = pinn.net[-1].bias.detach().numpy()

    u_recon = (H_recon @ W.T + b).reshape(nx, nt)
    u_mod   = (H_mod   @ W.T + b).reshape(nx, nt)

    delta = u_recon - u_mod

    return u_recon, u_mod, delta


# Visualization
def fig4(items):
    max_cols = max(len(x[-2]) for x in items)
    fig, axes = plt.subplots(len(items),max_cols,figsize=(18,16),constrained_layout=True)
    if len(items) == 1:
        axes = np.expand_dims(axes,0)

    for row, (pinn,kmeans,H,mu,sd,A,names,U,concepts_to_show,tag) in enumerate(items):

        for j_idx, cname in enumerate(concepts_to_show):

            j = names.index(cname)

            # top aligned cluster
            cluster = int(np.argmax(np.abs(A[:,j])))

            u_recon, u_mod, delta = intervene_ablate_kmeans(pinn,kmeans,H,mu,sd,cluster)

            ax = axes[row,j_idx]

            vmax = np.abs(delta).max()

            im = ax.imshow(np.abs(delta),extent=extent,origin="lower",aspect="auto",cmap="inferno",vmin=0,vmax=vmax if vmax>0 else 1)
            ax.contour(U,levels=[0.0],extent=extent,origin="lower",colors="cyan",linewidths=0.8,alpha=0.7)
            ax.set_title(
                f"{tag}: ablate Cluster {cluster}\n"
                f"(↔ {cname};",
                fontsize=9
            )

            ax.set_xlabel("$t$")

            if j_idx == 0:
                ax.set_ylabel("$x$")

            plt.colorbar(im,ax=ax,fraction=0.046,label=r"$|\Delta u|$")

        # hide unused columns

        for k in range(len(concepts_to_show), max_cols):
            axes[row,k].axis("off")

    plt.savefig(
        "figures/fig4_kmeans_intervention.png",
        bbox_inches="tight"
    )

    plt.show()


# Run
fig4([

    (pinn_b,kmeans_b,H_b,mu_b,sd_b,A_b,names_b,U_b,burgers_concepts_show,"Burgers"),
    (pinn_a,kmeans_a,H_a,mu_a,sd_a,A_a,names_a,U_a,ac_concepts_show,"Allen-Cahn"),
    (pinn_h,kmeans_h,H_h,mu_h,sd_h,A_h,names_h,U_h,heat_concepts_show,"Heat"),
    (conv_models[1],kmeans_c1,H_c1,mu_c1,sd_c1,A_c1,names_c1,U_c1,conv1_concepts_show,"Conv β=1"),
    (conv_models[50],kmeans_c50,H_c50,mu_c50,sd_c50,A_c50,names_c50,U_c50,conv50_concepts_show,"Conv β=50")
])

# %% [markdown]
# ## ablation for schrodinger - single and moving soliton

# %%
def intervene_ablate_schrodinger_kmeans(pinn,kmeans,H,mu,sd,cluster_idx):

    # Flatten hidden activations
    H_flat = H.reshape(-1, HIDDEN)
    # normalize
    H_norm = (H_flat - mu) / sd
    # Soft assignment to centroids
    D = kmeans.transform(H_norm)
    sigma = 0.25 * np.median(D)
    W_soft = np.exp(-(D**2) / (2 * sigma**2))
    W_soft /= W_soft.sum(axis=1, keepdims=True)

    # reconstruction
    H_recon_norm = W_soft @ kmeans.cluster_centers_

    # Ablate one centroid
    W_mod = W_soft.copy()
    W_mod[:, cluster_idx] = 0.0
    W_mod /= W_mod.sum(axis=1, keepdims=True) + 1e-12
    H_mod_norm = W_mod @ kmeans.cluster_centers_

    # Undo normalization
    H_recon = H_recon_norm * sd + mu
    H_mod   = H_mod_norm * sd + mu
    # Frozen PINN readout
    W = pinn.net[-1].weight.detach().numpy()
    b = pinn.net[-1].bias.detach().numpy()
    uv_recon = H_recon @ W.T + b
    uv_mod   = H_mod @ W.T + b
    u_recon = uv_recon[:,0].reshape(nx, nt)
    v_recon = uv_recon[:,1].reshape(nx, nt)
    u_mod = uv_mod[:,0].reshape(nx, nt)
    v_mod = uv_mod[:,1].reshape(nx, nt)
    amp_recon = np.sqrt(u_recon**2 + v_recon**2)
    amp_mod   = np.sqrt(u_mod**2 + v_mod**2)
    delta = np.sqrt((u_recon-u_mod)**2 +(v_recon-v_mod)**2)
    return amp_recon, amp_mod, delta


# Visualization
extent_s = [0,1,-5,5]

fig, axes = plt.subplots(2,7,figsize=(16,7),constrained_layout=True)
rows = [

    ("Single",pinn_s_s,kmeans_s_s,H_s_s,mu_s_s,sd_s_s,A_s_s,names_s_s,AMP_s_fig_single,sch_single_concepts_show),
    ("Moving",pinn_s_m,kmeans_s_m,H_s_m,mu_s_m,sd_s_m,A_s_m,names_s_m,AMP_s_fig_moving,sch_moving_concepts_show)
]

for row, (tag,pinn,kmeans,H,mu,sd,A,names,AMP_fig,concepts_show) in enumerate(rows):
    for j_idx, cname in enumerate(concepts_show):

        j = names.index(cname)

        # top aligned cluster
        cluster = int(np.argmax(np.abs(A[:, j])))

        amp_recon, amp_mod, delta = intervene_ablate_schrodinger_kmeans(pinn,kmeans,H,mu,sd,cluster)

        ax = axes[row, j_idx]

        vmax = np.abs(delta).max()

        im = ax.imshow(np.abs(delta),extent=extent_s,origin="lower",aspect="auto",cmap="inferno",vmin=0,vmax=vmax if vmax > 0 else 1)

        ax.contour(AMP_fig,levels=[1.0],extent=extent_s,origin="lower",colors="cyan",linewidths=0.8,alpha=0.7)

        ax.set_title(
            f"{tag}\n"
            f"Cluster {cluster}\n"
            f"{cname}\n",
            fontsize=8
        )

        ax.set_xlabel("$t$")

        if j_idx == 0:
            ax.set_ylabel("$x$")

        plt.colorbar(im,ax=ax,fraction=0.046,label=r"$|\Delta |h||$")

plt.suptitle("Schrödinger: Closed-loop K-Means Causal Ablation",fontsize=13)
plt.savefig("figures/fig4_schrodinger_kmeans_intervention.png",bbox_inches="tight")

plt.show()

# %% [markdown]
# ## Effective Support Fraction (ESF)
# Fraction of grid points needed to capture `frac` of the total |delta| energy Lower = the causal effect is concentrated in a smaller region (more spatially
# localized). Higher = the effect is smeared across the domain.

# %%
import pandas as pd
import contextlib
import io

def effective_support_fraction(delta, frac=0.8):
    flat = np.abs(delta).flatten()
    flat_sorted = np.sort(flat)[::-1]
    cumsum = np.cumsum(flat_sorted)
    total = cumsum[-1]
    if total <= 0:
        return 1.0
    threshold = frac * total
    n_needed = np.searchsorted(cumsum, threshold) + 1
    return n_needed / flat.size

rows = []

# ---- Non-Schrodinger PDEs (reuses intervene_ablate_kmeans) ----
non_sch_items = [
    (pinn_b, kmeans_b, H_b, mu_b, sd_b, A_b, names_b, burgers_concepts_show, "Burgers"),
    (pinn_a, kmeans_a, H_a, mu_a, sd_a, A_a, names_a, ac_concepts_show, "Allen-Cahn"),
    (pinn_h, kmeans_h, H_h, mu_h, sd_h, A_h, names_h, heat_concepts_show, "Heat"),
    (conv_models[1], kmeans_c1, H_c1, mu_c1, sd_c1, A_c1, names_c1, conv1_concepts_show, "Conv beta=1"),
    (conv_models[50], kmeans_c50, H_c50, mu_c50, sd_c50, A_c50, names_c50, conv50_concepts_show, "Conv beta=50"),
]

# intervene_ablate_kmeans prints diagnostic lines each call (sigma/weights) -
# suppress that noise here since we only want the rel_delta table
for pinn, kmeans, H, mu, sd, A, names, concepts_to_show, tag in non_sch_items:
    for cname in concepts_to_show:
        j = names.index(cname)
        cluster = int(np.argmax(np.abs(A[:, j])))
        with contextlib.redirect_stdout(io.StringIO()):
            u_recon, u_mod, delta = intervene_ablate_kmeans(pinn, kmeans, H, mu, sd, cluster)
        rel = np.linalg.norm(delta) / (np.linalg.norm(u_recon) + 1e-12)
        esf = effective_support_fraction(delta)
        rows.append({"method": "KMeans", "pde": tag, "concept": cname, "cluster": cluster, "rel_delta": rel, "esf80": esf})

# ---- Schrodinger (single + moving) ----
sch_items = [
    ("Schrodinger (Single)", pinn_s_s, kmeans_s_s, H_s_s, mu_s_s, sd_s_s, A_s_s, names_s_s, sch_single_concepts_show),
    ("Schrodinger (Moving)", pinn_s_m, kmeans_s_m, H_s_m, mu_s_m, sd_s_m, A_s_m, names_s_m, sch_moving_concepts_show),
]

for tag, pinn, kmeans, H, mu, sd, A, names, concepts_show in sch_items:
    for cname in concepts_show:
        j = names.index(cname)
        cluster = int(np.argmax(np.abs(A[:, j])))
        with contextlib.redirect_stdout(io.StringIO()):
            amp_recon, amp_mod, delta = intervene_ablate_schrodinger_kmeans(pinn, kmeans, H, mu, sd, cluster)
        rel = np.linalg.norm(delta) / (np.linalg.norm(amp_recon) + 1e-12)
        esf = effective_support_fraction(delta)
        rows.append({"method": "KMeans", "pde": tag, "concept": cname, "cluster": cluster, "rel_delta": rel, "esf80": esf})

df_kmeans = pd.DataFrame(rows)
pd.set_option("display.width", 120)
print(df_kmeans.to_string(index=False))
print(f"\nMean rel_delta = {df_kmeans['rel_delta'].mean():.4f}   Mean ESF80 = {df_kmeans['esf80'].mean():.4f}")
df_kmeans.to_csv("kmeans_rel_delta.csv", index=False)
print("Saved to kmeans_rel_delta.csv")
# Out:
# method                  pde                           concept  cluster  rel_delta    esf80
# KMeans              Burgers                        u (signed)       48   0.008352 0.248672
# KMeans              Burgers                     |u_x| (shock)       79   0.005000 0.112422
# KMeans              Burgers                       dist to x=0       69   0.010358 0.182383
# KMeans              Burgers                          t (time)       95   0.010089 0.020898
# KMeans           Allen-Cahn                        u (signed)       63   0.000669 0.359883
# KMeans           Allen-Cahn                 |u_x| (interface)       10   0.000576 0.379258
# KMeans           Allen-Cahn         interface (exp(-u^2/0.1))      117   0.000490 0.373750
# KMeans           Allen-Cahn                          t (time)      104   0.002070 0.066562
# KMeans                 Heat                               |u|      120   0.013450 0.008320
# KMeans                 Heat                  |u_x| (gradient)      112   0.007155 0.319180
# KMeans                 Heat                             |u_t|      120   0.013450 0.008320
# KMeans                 Heat                |u_xx| (curvature)      120   0.013450 0.008320
# KMeans                 Heat                          t (time)       44   0.006565 0.306133
# KMeans          Conv beta=1                               |u|       41   0.013680 0.106758
# KMeans          Conv beta=1           |u_x| (transport front)       47   0.014956 0.057578
# KMeans          Conv beta=1                             |u_t|       47   0.014956 0.057578
# KMeans          Conv beta=1                        u (signed)      112   0.008347 0.155742
# KMeans          Conv beta=1                        x position       36   0.012613 0.125898
# KMeans          Conv beta=1                          t (time)        9   0.011328 0.135586
# KMeans          Conv beta=1              characteristic (x-t)       59   0.011453 0.056602
# KMeans         Conv beta=50                               |u|      105   0.001960 0.009375
# KMeans         Conv beta=50           |u_x| (transport front)       75   0.000843 0.737617
# KMeans         Conv beta=50                             |u_t|       30   0.007561 0.000625
# KMeans         Conv beta=50                        u (signed)      100   0.005587 0.000742
# KMeans         Conv beta=50                        x position       25   0.000245 0.608867
# KMeans         Conv beta=50                          t (time)       85   0.000484 0.673984
# KMeans         Conv beta=50            characteristic (x-50t)       53   0.000472 0.680078
# KMeans Schrodinger (Single)                   |h| (amplitude)      116   0.004076 0.117461
# KMeans Schrodinger (Single)                          u (real)       99   0.005736 0.052266
# KMeans Schrodinger (Single)                          v (imag)       84   0.003646 0.184102
# KMeans Schrodinger (Single)                |h_x| (wave-front)       79   0.004147 0.170742
# KMeans Schrodinger (Single)                  |h_t| (temporal)       99   0.005736 0.052266
# KMeans Schrodinger (Single)                       phi (phase)       41   0.005096 0.128789
# KMeans Schrodinger (Single)                          t (time)       41   0.005096 0.128789
# KMeans Schrodinger (Moving)                   |h| (amplitude)      125   0.008386 0.082266
# KMeans Schrodinger (Moving)                          u (real)       82   0.009376 0.068359
# KMeans Schrodinger (Moving)                          v (imag)       87   0.008404 0.069883
# KMeans Schrodinger (Moving)                |h_x| (wave-front)       85   0.009283 0.051602
# KMeans Schrodinger (Moving)                  |h_t| (temporal)       28   0.002728 0.170117
# KMeans Schrodinger (Moving)                       phi (phase)       90   0.006723 0.080039
# KMeans Schrodinger (Moving) distance to moving soliton center       40   0.007739 0.121406
#
# Mean rel_delta = 0.0069   Mean ESF80 = 0.1775
# Saved to kmeans_rel_delta.csv
